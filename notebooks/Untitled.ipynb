# %%
# !pip install psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 27.5 MB/s eta 0:00:0000:0100:01
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('postgresql://dwh_admin:dwh_secure_password@postgres-dwh:5432/b2b_mobile_money_dwh')

# %%
# Test de connexion
df = pd.read_sql("SELECT * FROM dwh.dim_date LIMIT 10", engine)
df.head()
# Out:
#    date_key   full_date  day_of_week   day_name  day_of_month  day_of_year  \
# 0         1  2022-01-01            6  Saturday              1            1
# 1         2  2022-01-02            0  Sunday                2            2
# 2         3  2022-01-03            1  Monday                3            3
# 3         4  2022-01-04            2  Tuesday               4            4
# 4         5  2022-01-05            3  Wednesday             5            5
#
#    week_of_year  month_number month_name  quarter  year  is_weekend  \
# 0            52             1  January          1  2022        True
# 1            52             1  January          1  2022        True
# 2             1             1  January          1  2022       False
# 3             1             1  January          1  2022       False
# 4             1             1  January          1  2022       False
#
#   is_holiday  fiscal_year  fiscal_quarter                 created_at
# ...

# %%
# Test de connexion
df = pd.read_sql("SELECT * FROM dwh.dim_client LIMIT 10", engine)
df.head()
# Out:
# Empty DataFrame
# Columns: [client_key, client_id, company_name, industry_sector, company_size, registration_date, country, city, region, account_manager, customer_segment, credit_score, risk_level, is_active, kyc_status, valid_from, valid_to, is_current, created_at, updated_at]
# Index: []

# %%
# Test de connexion
df = pd.read_sql("SELECT * FROM dwh.fact_transactions LIMIT 10", engine)
df.head()
# Out:
# Empty DataFrame
# Columns: [transaction_key, transaction_id, date_key, time_key, client_key, service_key, channel_key, status_key, geography_key, transaction_amount, commission_amount, net_amount, currency_code, recipient_count, processing_time_seconds, fraud_score, is_fraud, fraud_type, created_at, processed_at]
# Index: []
